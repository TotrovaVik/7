# %% [markdown]
# # Введение в обработку текста на естественном языке

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 9: Введение в обработку текста на естественном языке\
# * https://realpython.com/nltk-nlp-python/
# * https://scikit-learn.org/stable/modules/feature_extraction.html

# %% [markdown]
# ## Задачи для совместного разбора

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pymorphy2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-223a39775638> in <cell line: 2>()
#       1 from sklearn.feature_extraction.text import CountVectorizer
# ----> 2 import pymorphy2
#
# ModuleNotFoundError: No module named 'pymorphy2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# 1. Считайте слова из файла `litw-win.txt` и запишите их в список `words`. В заданном предложении исправьте все опечатки, заменив слова с опечатками на ближайшие (в смысле расстояния Левенштейна) к ним слова из списка `words`. Считайте, что в слове есть опечатка, если данное слово не содержится в списке `words`.

# %%
text = '''с велечайшим усилием выбравшись из потока убегающих людей Кутузов со свитой уменьшевшейся вдвое поехал на звуки выстрелов русских орудий'''

# %% [markdown]
# 2. Разбейте текст из формулировки задания 1 на слова; проведите стемминг и лемматизацию слов.

# %% [markdown]
# 3. Преобразуйте предложения из формулировки задания 1 в векторы при помощи `CountVectorizer`.

# %% [markdown]
# ## Лабораторная работа 9

# %% [markdown]
# ### Расстояние редактирования

# %% [markdown]
# 1.1 Загрузите предобработанные описания рецептов из файла `preprocessed_descriptions.csv`. Получите набор уникальных слов `words`, содержащихся в текстах описаний рецептов (воспользуйтесь `word_tokenize` из `nltk`).

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')

data = pd.read_csv('preprocessed_descriptions.csv')
descriptions = data['description'].dropna()

words = set()
for description in descriptions:
    tokens = word_tokenize(description)
    words.update(tokens)

print(words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# {'smoothie-style', 'chest', '1980s', '4.1g', 'summer', 'jean-georges', 'dante', 'lamme', 'harbor', 'zaarian', 'cheez-its', 'shaped', '51349.', 'pages', 'remodeled', 'liberia', 'ones', 'feeling', '1-pot', 'marie', 'cast', 'emmantaler', 'jalapenos', 'dollar', 'flans', 'baba', 'geschnetzeltes', 'removal', 'soy/oil', 'shakelike', 'kadami', 'also.i', 'centuries', 'goodie', 'forefront', 'prized', 'wally', 'brooklyn', 'discribed', 'booklet.i', 'handeling', 'half-way', 'focaccia', 'marjoram', 'stools', 'masterfoods', 'etc.', 'dlife', 'helga', 'when', 'tori', 'flowerets', 'kettle', 'litte', 'enjoyed.time', 'gi', 'hellman', 'cheryl', 'aborio', 'ganache-', 'desired', 'garlic-thyme', 'sat.fat', 'tone', 'ballet', 'cattlemens', 'virtuous', 'brick', 'kirstie', 'mice', '1952', 'desided', 'bueno', 'spicing', 'feedback', 'germain', 'characteristic', 'adjusting', 'peasy', 'pyramid', 'rugelach', 'campus', 'romance', 'goldmine', 'anglo-indian', 'realistically', '250', 'mix-n-match', 'instructs', 'mojo', 'fudge/softball', 'fooled', '1,000', 'chefmd', 'slater', 'sindhi', 'flier', 'tendency', 'women', 'asadero', 'goan/south', 'lebonese', 'loaded', 'beefsteak', '19,2010', 'brilliantly', '3-layered', 'sorts', 'cake/brownies', 'holding', 'containter', 'suggestions—drizzle', 'tender-crisp', 'refried', 'soup-friendly', 'b', 'step-sister', 'warm-up', 'energy', 'snazzy', 'podcast', 'sweet.i', 'guinna', 'ingredients-', 'poo', 'w/tortillas', 'pasta', 'algerian', 'www.thaifoodandtravel.com', 'already-simmered', 'standbys', 'ability', 'weis', 'author/chef', 'vanilla-spiked', "'tate", 'monkeyed', '700g', 'alfalfa', 'robbins', 'brown-colored', 'nobu', 'betray', 'also-', 'favor', 'wasting', 'garnered', 'lol-he', 'get-', 'lard', 'cone-shaped', '387', 'walks', 'amateur', 'hesitated', 'simple-to-make', 'transform', 'drab', 'symply', 'spritzkuchen', 'pre-browned', 'toghther', 'spinach/feta', 'pushing', '2004.', 'anywhere', 'conch', 'fork', 'disasterous', 'wonderbread', 'pilma', 'de-seeding', 'photo.after', 'weekend', 'organ', 'fargo', "'pizza", 'moistened', 'so-do', 'someones', 'ingredients…i', 'coffees', 'definatley', 'estimated.if', 'gringos', 'dooky', 'sauteeing', 'vjje', 'molasses-baked', 'spectacular', 'estimations', 'frosting-', '//bit.ly/7bwgul', 'sugars', 'shoot', 'luscious-sounding', 'dazzle', 'ely', 'paradise', 'nite', 'mucky', 'ooh', 'perhaps', 'wah', 'nbc', 'basa', '30min', 'jess96', 'noticing', 'term', 'prossessor', 'zum', 'pies', 'chayote', 'w/all', 'durham', 'hairstylist', 'binnurs', 'interim', 'wake-up', 'babara', 'greasy', 'spinner', 'seoul', 'third', 'zone', 'garvin', 'sterile', 'rut', 'realize', 'aaronson', 'spirals', '//thymefornourishment.wordpress.com/2009/04/05/general-tsos-shrimp/', 'pre-nuking', "5th-11th'06", 'dinosaur', 'kapoor', 'personally', 'isa', 'ethel', 'leicester', 'yogurts', 'smoothness', 'choccie', 'elimiante', 'searches', 'massive', '25-30', 'evertime', 'plopped', 'nobody', '373181', 'farfel', 'melanie', 'eggless', 'mess', 'china', 'highly-seasoned', 'baldacci', 'chavroux', 'morcom', 'grms', 'dredge', 'visko', 'rise', 'healthier', 'breading', 'panko', 'purees', 'cheese/neufchatel', '1973.', 'mish', 'decidedly', 'lover', 'carino', 'lustreless', 'smiled', 'desserts', 'schuhmacher', 'blobs', 'decident', 'biscuits', 'filo', 'depend', 'mother-in', 'seneca', 'denver', 'winter/spring', 'aaaahing', 'guaranteed', 'unfair', 'contessa/ina', 'scale', 'baggies', 'bare', 'airy', "would'nt", 'printable', 'ingredients.a', 'meeting', 'winner-no', 'www.glutenfreegirls.blogspot.com', 'harmon', 'misc', 'l.a.', 'berenbaum', 'impart', 'untoasted', 'choir', 'career', 'serviettes', 'remaining', 'very-high-fat', '790', 'knead', 'baileys', 'broaden', 'wheat-free/gluten-free', 'aye', 'central', 'hollowed', 'sinless', 'behalf', 'hodgon', 'constitution', 'carniverous', 'calorie-conscious', 'woe', 'purim', 'royers', 'denti', 'birdseed', 'rutabaga', 'peta', 'severe', 'stewing', 'chef2chef', 'jayson', 'schweinebraten', 'guarded', 'higher-sodium', 'cauliflower', ' ...

# %% [markdown]
# 1.2 Сгенерируйте 5 пар случайно выбранных слов и посчитайте между ними расстояние редактирования.

# %%
pip install Levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Levenshtein
#   Downloading Levenshtein-0.21.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 10.8 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0
#   Downloading rapidfuzz-3.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 73.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.21.0 rapidfuzz-3.0.0

# %%
import random
from Levenshtein import distance as levenshtein_distance

random_word_pairs = [(random.choice(list(words)), random.choice(list(words))) for _ in range(5)]

for pair in random_word_pairs:
    dist = levenshtein_distance(pair[0], pair[1])
    print(f"Расстояние редактирования между '{pair[0]}' и '{pair[1]}': {dist}")
# Out:
# Расстояние редактирования между '6th-12th'06' и 'fluffy': 11
# Расстояние редактирования между 'count' и 'knead': 5
# Расстояние редактирования между 'everybody' и 'vegan': 7
# Расстояние редактирования между 'office' и 'realized': 6
# Расстояние редактирования между 'bit' и 'recommend': 9

# %% [markdown]
# 1.3 Напишите функцию, которая для заданного слова `word` возвращает `k` ближайших к нему слов из списка `words` (близость слов измеряется с помощью расстояния Левенштейна)

# %%
def find_closest_words(word, words, k=5):
    distances = [(w, levenshtein_distance(word, w)) for w in words]
    distances.sort(key=lambda x: x[1])
    return [w[0] for w in distances[:k]]

word = "example"
closest_words = find_closest_words(word, words)
print(f"{word} ближайшие слова: {closest_words}")
# Out:
# example ближайшие слова: ['maple', 'simple', 'couple', 'email', 'excuse']

# %% [markdown]
# ### Стемминг, лемматизация

# %% [markdown]
# 2.1 На основе результатов 1.1 создайте `pd.DataFrame` со столбцами:
#     * word
#     * stemmed_word
#     * normalized_word
#
# Столбец `word` укажите в качестве индекса.
#
# Для стемминга воспользуйтесь `SnowballStemmer`, для нормализации слов - `WordNetLemmatizer`. Сравните результаты стемминга и лемматизации.

# %%
from nltk.stem import SnowballStemmer, WordNetLemmatizer
nltk.download('wordnet')

stemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

word_data = []

for w in words:
    stemmed_word = stemmer.stem(w)
    normalized_word = lemmatizer.lemmatize(w)
    word_data.append({"word": w, "stemmed_word": stemmed_word, "normalized_word": normalized_word})

word_df = pd.DataFrame(word_data).set_index('word')
print(word_df)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#            stemmed_word normalized_word
# word
# actual           actual          actual
# cheddar         cheddar         cheddar
# more               more            more
# peas                pea             pea
# couple            coupl          couple
# ...                 ...             ...
# mind               mind            mind
# cake               cake            cake
# of                   of              of
# loves              love            love
# unbeatable       unbeat      unbeatable
#
# [1953 rows x 2 columns]

# %% [markdown]
# 2.2. Удалите стоп-слова из описаний рецептов. Какую долю об общего количества слов составляли стоп-слова? Сравните топ-10 самых часто употребляемых слов до и после удаления стоп-слов.

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def remove_stopwords(text, stop_words):
    tokens = word_tokenize(text)
    filtered_tokens = [token for token in tokens if token.lower() not in stop_words]
    return ' '.join(filtered_tokens)

filtered_descriptions = data['description'].dropna().apply(lambda x: remove_stopwords(x, stop_words))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
total_word_count = sum([len(word_tokenize(desc)) for desc in descriptions])
filtered_word_count = sum([len(word_tokenize(desc)) for desc in filtered_descriptions])
stopword_count = total_word_count - filtered_word_count
stopword_ratio = stopword_count / total_word_count

print(f"Доля стоп-слов: {stopword_ratio:.2f}")
# Out:
# Доля стоп-слов: 0.40

# %% [markdown]
# ### Векторное представление текста

# %% [markdown]
# 3.1 Выберите случайным образом 5 рецептов из набора данных. Представьте описание каждого рецепта в виде числового вектора при помощи `TfidfVectorizer`

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

sampled_data = data.sample(5)
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(sampled_data['description'])

# %% [markdown]
# 3.2 Вычислите близость между каждой парой рецептов, выбранных в задании 3.1, используя косинусное расстояние (`scipy.spatial.distance.cosine`) Результаты оформите в виде таблицы `pd.DataFrame`. В качестве названий строк и столбцов используйте названия рецептов.

# %%
from scipy.spatial.distance import cosine
import numpy as np

cosine_similarities = np.zeros((5, 5))
recipe_names = sampled_data['name'].values

for i in range(5):
    for j in range(5):
        cosine_similarities[i, j] = 1 - cosine(tfidf_matrix[i].toarray().flatten(), tfidf_matrix[j].toarray().flatten())

similarity_df = pd.DataFrame(cosine_similarities, columns=recipe_names, index=recipe_names)
print(similarity_df)
# Out:
#                                                ham and cheese breakfast strudels  \
# ham and cheese breakfast strudels                                       1.000000
# smothered rabbit with tarragon sauce  chicken                           0.091840
# coconut lime shrimp skewers                                             0.243275
# lemon tarragon chicken with pan sauce                                   0.062167
# pork chops in creamy herbed brandy sauce                                0.270870
#
#                                                smothered rabbit with tarragon sauce  chicken  \
# ham and cheese breakfast strudels                                                   0.091840
# smothered rabbit with tarragon sauce  chicken                                       1.000000
# coconut lime shrimp skewers                                                         0.096005
# lemon tarragon chicken with pan sauce                                               0.046083
# pork chops in creamy herbed brandy sauce                                            0.204848
#
#                                                coconut lime shrimp skewers  \
# ham and cheese breakfast strudels                                 0.243275
# smothered rabbit with tarragon sauce  chicken                     0.096005
# coconut lime shrimp skewers                                       1.000000
# lemon tarragon chicken with pan sauce                             0.040252
# pork chops in creamy herbed brandy sauce                          0.162171
#
#                                                lemon tarragon chicken with pan sauce  \
# ham and cheese breakfast strudels                                           0.062167
# smothered rabbit with tarragon sauce  chicken                               0.046083
# coconut lime shrimp skewers                                                 0.040252
# lemon tarragon chicken with pan sauce                                       1.000000
# pork chops in creamy herbed brandy sauce                                    0.000000
#
#                                                pork chops in creamy herbed brandy sauce
# ham and cheese breakfast strudels                                              0.270870
# smothered rabbit with tarragon sauce  chicken                                  0.204848
# coconut lime shrimp skewers                                                    0.162171
# lemon tarragon chicken with pan sauce                                          0.000000
# pork chops in creamy herbed brandy sauce                                       1.000000

# %% [markdown]
# 3.3 Какие рецепты являются наиболее похожими? Прокомментируйте результат (словами).

# %%
most_similar_value = -1
most_similar_pair = None

for i in range(5):
    for j in range(5):
        if i != j and cosine_similarities[i, j] > most_similar_value:
            most_similar_value = cosine_similarities[i, j]
            most_similar_pair = (i, j)

print(f"Наиболее похожие рецепты: '{recipe_names[most_similar_pair[0]]}' и '{recipe_names[most_similar_pair[1]]}'. Косинусное расстояние: {most_similar_value:.2f}")
# Out:
# Наиболее похожие рецепты: 'ham and cheese breakfast strudels' и 'pork chops in creamy herbed brandy sauce'. Косинусное расстояние: 0.27
